# %%
import wave,os,glob,librosa
import numpy as np
import librosa.display
import scipy.io.wavfile as wav
import scipy.signal as signal
import matplotlib.pyplot as plt
import time

# %%
fig, axs = plt.subplots(3)
i=0;
path =r"C:\Users\Niraj\Desktop\just like that\inGenius\spec"
for filename in glob.glob(os.path.join(path, '*.wav')):
    x, sr = librosa.load(filename)
    axs[i].specgram(x,Fs=sr)
    i=i+1

# %%
#fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True)
path =r"C:\Users\Niraj\Desktop\just like that\inGenius\spec"
for filename in glob.glob(os.path.join(path, '*.wav')):
    x, sr = librosa.load(filename)
    #sample_rate, samples = wav.read(filename)
    #print("spec")
    #librosa.display.specshow(x,sr=sr)
    #frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)
    #plt.pcolormesh(times, frequencies, spectrogram) #the time series does not make sense when i just flatten the data. it is now twice as long.
    #plt.imshow(spectrogram)
    #plt.ylabel('Frequency [Hz]')
    #plt.xlabel('Time [sec]')
    #plt.show()
    plt.specgram(x, Fs=sample_rate)
    print("fter spectrogrm")
    #time.sleep(2)
#print(x)
    #f, t, Zxx = signal.stft(samples, fs=sample_rate)
#plt.plot(samples)

#print(x)
# Out:
# fter spectrogrm
# fter spectrogrm
# fter spectrogrm

# %%
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-91-d6579f534729> in <module>()
# ----> 1 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'
